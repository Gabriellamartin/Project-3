# %%
import pandas as pd
#import matplotlib.pyplot as plt
#import seaborn as sea
#import os
#import numpy as np
#from sklearn.model_selection import train_test_split
#from sklearn.linear_model import PoissonRegressor
#from sklearn.experimental import enable_hist_gradient_boosting  # noqa
#from sklearn.ensemble import HistGradientBoostingRegressor
import chardet
from sqlalchemy import create_engine
engine = create_engine('postgresql://postgres:Bonesaw14!@localhost:5432/project-3')

# %%
path_city = r"\Users\Kaleb\Project-3\CityofChicagoMBE_2021-02-27_179.csv"
path_county = r"\Users\Kaleb\Project-3\CookCountyMBE_2021-02-27_349.csv"
path_state = r"\Users\Kaleb\Project-3\StateOfIllinoisMBE_2021-02-27_368.csv"

# %%
with open(path_city, 'rb') as rawdata:
    result = chardet.detect(rawdata.read(100000))
result

with open(path_county, 'rb') as rawdata:
    result = chardet.detect(rawdata.read(100000))
result


with open(path_state, 'rb') as rawdata:
    result = chardet.detect(rawdata.read(100000))
result
# Out:
# {'encoding': 'ascii', 'confidence': 1.0, 'language': ''}

# %%
city_data = pd.read_csv(path_city,encoding='ISO-8859-1')
city_data
# Out:
#                                      company_name  \
# 0             *PRADO & RENTERIA CPAS, Prof. Corp.
# 1             *PRADO & RENTERIA CPAS, Prof. Corp.
# 2                1st Call Technical Services, Inc
# 3     1st Metropolitan Translation Services, Inc.
# 4                      1st Priority Elevator, Co.
# ...                                           ...
# 3819                             ZOI Incorporated
# 3820                               Zoka Zola, LLC
# 3821                                          NaN
# 3822                                          NaN
# 3823            Generated from the B2Gnow System.
#
#                                    dba_name owner_first owner_last  \
# 0                                     Corp.  Maria de J      Prado
# 1                                     Corp.  Maria de J      Prado
# 2                                       NaN         Ron      Olson
# 3                                       NaN     Shannon    Ewasiuk
# ...

# %%
county_data = pd.read_csv(path_county,encoding='ISO-8859-1')
county_data
# Out:
#                                      company_name  \
# 0             *PRADO & RENTERIA CPAS, Prof. Corp.
# 1             *PRADO & RENTERIA CPAS, Prof. Corp.
# 2                1st Call Technical Services, Inc
# 3     1st Metropolitan Translation Services, Inc.
# 4                      1st Priority Elevator, Co.
# ...                                           ...
# 4651                               Zoka Zola, LLC
# 4652                               Zoka Zola, LLC
# 4653                                          NaN
# 4654                                          NaN
# 4655            Generated from the B2Gnow System.
#
#                                    dba_name owner_first owner_last  \
# 0                                     Corp.  Maria de J      Prado
# 1                                     Corp.  Maria de J      Prado
# 2                                       NaN         Ron      Olson
# 3                                       NaN     Shannon    Ewasiuk
# ...

# %%
state_data = pd.read_csv(path_state,encoding='ISO-8859-1')
state_data
# Out:
#                                    company_name                  dba_name  \
# 0                                #9 Design, LLC  North Arrow Architecture
# 1           *PRADO & RENTERIA CPAS, Prof. Corp.                       NaN
# 2                   .VIZ CONSULTING CORPORATION                       NaN
# 3     1776 American Valor Medical Supplies Inc.                       NaN
# 4              1st Call Technical Services, Inc                       NaN
# ...                                         ...                       ...
# 3462                           Zuber Lawler LLP                       NaN
# 3463                        ZZM Investments Inc                       NaN
# 3464                                        NaN                       NaN
# 3465                                        NaN                       NaN
# 3466          Generated from the B2Gnow System.                       NaN
#
#      owner_first owner_last             physical_address          city state  \
# ...

# %%
city_data.to_sql('city_data', engine)
county_data.to_sql('county_data', engine)
state_data.to_sql('state_data', engine)
